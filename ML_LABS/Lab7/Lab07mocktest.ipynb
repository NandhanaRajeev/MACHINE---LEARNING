# %%
import pandas as pd

df=pd.read_csv("nasav3.csv")
df
# Out:
#       Absolute Magnitude  Est Dia in KM(min)  Est Dia in KM(max)  \
# 0                 21.600            0.127220            0.284472
# 1                 21.300            0.146068            0.326618
# 2                 20.300            0.231502            0.517654
# 3                 27.400            0.008801            0.019681
# 4                 21.600            0.127220            0.284472
# ...                  ...                 ...                 ...
# 4682              23.900            0.044112            0.098637
# 4683              28.200            0.006089            0.013616
# 4684              22.700            0.076658            0.171412
# 4685              21.800            0.116026            0.259442
# 4686              19.109            0.400641            0.895860
#
#       Est Dia in M(min)  Est Dia in M(max)  Est Dia in Miles(min)  \
# 0            127.219878         284.472297               0.079051
# 1            146.067964         326.617897               0.090762
# 2            231.502122         517.654482               0.143849
# 3              8.801465          19.680675               0.005469
# 4            127.219878         284.472297               0.079051
# ...                 ...                ...                    ...
# 4682          44.111820          98.637028               0.027410
# 4683           6.089126          13.615700               0.003784
# 4684          76.657557         171.411509               0.047633
# 4685         116.025908         259.441818               0.072095
# 4686         400.640618         895.859655               0.248946
#
#       Est Dia in Miles(max)  Est Dia in Feet(min)  Est Dia in Feet(max)  \
# 0                  0.176763            417.388066            933.308089
# 1                  0.202951            479.225620           1071.581063
# 2                  0.321655            759.521423           1698.341531
# 3                  0.012229             28.876199             64.569144
# 4                  0.176763            417.388066            933.308089
# ...                     ...                   ...                   ...
# 4682               0.061290            144.723824            323.612307
# 4683               0.008460             19.977449             44.670934
# 4684               0.106510            251.501181            562.373736
# 4685               0.161210            380.662441            851.187094
# 4686               0.556661           1314.437764           2939.172192
#
#       Close Approach Date  ... Asc Node Longitude  Orbital Period  \
# 0                      71  ...         314.373913      609.599786
# 1                      71  ...         136.717242      425.869294
# 2                      78  ...         259.475979      643.580228
# 3                      85  ...          57.173266      514.082140
# 4                      85  ...          84.629307      495.597821
# ...                   ...  ...                ...             ...
# 4682                 7992  ...         164.183305      457.179984
# 4683                 7992  ...         345.225230      407.185767
# 4684                 7992  ...          37.026468      690.054279
# 4685                 7992  ...         163.802909      662.048343
# 4686                 7992  ...         187.642183      653.679098
#
#       Perihelion Distance  Perihelion Arg  Aphelion Dist  Perihelion Time  \
# 0                0.808259       57.257470       2.005764      2458161.642
# 1                0.718200      313.091975       1.497352      2457794.969
# 2                0.950791      248.415038       1.966857      2458120.468
# 3                0.983902       18.707701       1.527904      2457902.337
# 4                0.967687      158.263596       1.483543      2457814.455
# ...                   ...             ...            ...              ...
# 4682             0.741558      276.395697       1.581299      2457708.228
# 4683             0.996434       42.111064       1.153835      2458087.617
# 4684             0.965760      274.692712       2.090708      2458300.480
# 4685             1.185467      180.346090       1.787733      2458288.261
# 4686             0.876110      222.436688       2.071980      2458318.587
#
#       Mean Anomaly  Mean Motion  Equinox  Hazardous
# 0       264.837533     0.590551     2000          1
# 1       173.741112     0.845330     2000          0
# 2       292.893654     0.559371     2000          1
# 3        68.741007     0.700277     2000          0
# 4       135.142133     0.726395     2000          1
# ...            ...          ...      ...        ...
# 4682    304.306024     0.787436     2000          0
# 4683    282.978786     0.884117     2000          0
# 4684    203.501147     0.521698     2000          0
# 4685    203.524965     0.543767     2000          0
# 4686    184.820424     0.550729     2000          0
#
# [4687 rows x 40 columns]

# %%
df.shape
df.columns
# Out:
# Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
#        'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
#        'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
#        'Close Approach Date', '22-10-1994', 'Epoch Date Close Approach',
#        'Relative Velocity km per sec', 'Relative Velocity km per hr',
#        'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
#        'Orbit ID', 'Orbit Determination Date', 'no', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Equinox', 'Hazardous'],
#       dtype='object')

# %%
df.drop("22-10-1994",axis=1,inplace=True)
df.drop("no",axis=1,inplace=True)
df.columns
# Out:
# Index(['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
#        'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
#        'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
#        'Close Approach Date', 'Epoch Date Close Approach',
#        'Relative Velocity km per sec', 'Relative Velocity km per hr',
#        'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
#        'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
#        'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
#        'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
#        'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
#        'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
#        'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
#        'Mean Motion', 'Equinox', 'Hazardous'],
#       dtype='object')

# %%
label = df["Hazardous"]
x = df.drop("Hazardous",axis=1)
features = ['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
       'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
       'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
       'Close Approach Date', 'Epoch Date Close Approach',
       'Relative Velocity km per sec', 'Relative Velocity km per hr',
       'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
       'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
       'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
       'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
       'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
       'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
       'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
       'Mean Motion', 'Equinox']
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x,label,
                                   random_state=104,  
                                   test_size=0.25,  
                                   shuffle=True)
print(label)
print(x)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 4682    0
# 4683    0
# 4684    0
# 4685    0
# 4686    0
# Name: Hazardous, Length: 4687, dtype: int64
#       Absolute Magnitude  Est Dia in KM(min)  Est Dia in KM(max)  \
# 0                 21.600            0.127220            0.284472
# 1                 21.300            0.146068            0.326618
# 2                 20.300            0.231502            0.517654
# 3                 27.400            0.008801            0.019681
# 4                 21.600            0.127220            0.284472
# ...                  ...                 ...                 ...
# 4682              23.900            0.044112            0.098637
# 4683              28.200            0.006089            0.013616
# 4684              22.700            0.076658            0.171412
# 4685              21.800            0.116026            0.259442
# 4686              19.109            0.400641            0.895860
#
#       Est Dia in M(min)  Est Dia in M(max)  Est Dia in Miles(min)  \
# 0            127.219878         284.472297               0.079051
# 1            146.067964         326.617897               0.090762
# 2            231.502122         517.654482               0.143849
# 3              8.801465          19.680675               0.005469
# 4            127.219878         284.472297               0.079051
# ...                 ...                ...                    ...
# 4682          44.111820          98.637028               0.027410
# 4683           6.089126          13.615700               0.003784
# 4684          76.657557         171.411509               0.047633
# 4685         116.025908         259.441818               0.072095
# 4686         400.640618         895.859655               0.248946
#
#       Est Dia in Miles(max)  Est Dia in Feet(min)  Est Dia in Feet(max)  \
# 0                  0.176763            417.388066            933.308089
# 1                  0.202951            479.225620           1071.581063
# 2                  0.321655            759.521423           1698.341531
# 3                  0.012229             28.876199             64.569144
# 4                  0.176763            417.388066            933.308089
# ...                     ...                   ...                   ...
# 4682               0.061290            144.723824            323.612307
# 4683               0.008460             19.977449             44.670934
# 4684               0.106510            251.501181            562.373736
# 4685               0.161210            380.662441            851.187094
# 4686               0.556661           1314.437764           2939.172192
#
#       Close Approach Date  ...  Inclination  Asc Node Longitude  \
# 0                      71  ...     6.025981          314.373913
# 1                      71  ...    28.412996          136.717242
# 2                      78  ...     4.237961          259.475979
# 3                      85  ...     7.905894           57.173266
# 4                      85  ...    16.793382           84.629307
# ...                   ...  ...          ...                 ...
# 4682                 7992  ...    39.880491          164.183305
# 4683                 7992  ...     5.360249          345.225230
# 4684                 7992  ...     4.405467           37.026468
# 4685                 7992  ...    21.080244          163.802909
# 4686                 7992  ...    53.574922          187.642183
#
#       Orbital Period  Perihelion Distance  Perihelion Arg  Aphelion Dist  \
# 0         609.599786             0.808259       57.257470       2.005764
# 1         425.869294             0.718200      313.091975       1.497352
# 2         643.580228             0.950791      248.415038       1.966857
# 3         514.082140             0.983902       18.707701       1.527904
# 4         495.597821             0.967687      158.263596       1.483543
# ...              ...                  ...             ...            ...
# 4682      457.179984             0.741558      276.395697       1.581299
# 4683      407.185767             0.996434       42.111064       1.153835
# 4684      690.054279             0.965760      274.692712       2.090708
# 4685      662.048343             1.185467      180.346090       1.787733
# 4686      653.679098             0.876110      222.436688       2.071980
#
#       Perihelion Time  Mean Anomaly  Mean Motion  Equinox
# 0         2458161.642    264.837533     0.590551     2000
# 1         2457794.969    173.741112     0.845330     2000
# 2         2458120.468    292.893654     0.559371     2000
# 3         2457902.337     68.741007     0.700277     2000
# 4         2457814.455    135.142133     0.726395     2000
# ...               ...           ...          ...      ...
# 4682      2457708.228    304.306024     0.787436     2000
# 4683      2458087.617    282.978786     0.884117     2000
# 4684      2458300.480    203.501147     0.521698     2000
# 4685      2458288.261    203.524965     0.543767     2000
# 4686      2458318.587    184.820424     0.550729     2000
#
# [4687 rows x 37 columns]

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt



clf = DecisionTreeClassifier(criterion='gini',max_depth=3)
clf = clf.fit(X_train, y_train)

tree.plot_tree(clf,feature_names=features)
print(X_train.shape)
# Out:
# (3515, 37)

# %%
from sklearn.metrics import accuracy_score
predicted = clf.predict(X_train)
print (accuracy_score(y_train, predicted))
# Out:
# 0.9954480796586059

# %%
from sklearn.metrics import accuracy_score
predicted = clf.predict(X_test)
print (accuracy_score(y_test, predicted))
# Out:
# 0.9948805460750854

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predicted)
# Out:
# array([[988,   0],
#        [  6, 178]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00       988
#            1       1.00      0.97      0.98       184
#
#     accuracy                           0.99      1172
#    macro avg       1.00      0.98      0.99      1172
# weighted avg       0.99      0.99      0.99      1172

# %%
features = ['Absolute Magnitude', 'Est Dia in KM(min)', 'Est Dia in KM(max)',
       'Est Dia in M(min)', 'Est Dia in M(max)', 'Est Dia in Miles(min)',
       'Est Dia in Miles(max)', 'Est Dia in Feet(min)', 'Est Dia in Feet(max)',
       'Close Approach Date', 'Epoch Date Close Approach',
       'Relative Velocity km per sec', 'Relative Velocity km per hr',
       'Miles per hour', 'Miss Dist.(Astronomical)', 'Miss Dist.(lunar)',
       'Miss Dist.(kilometers)', 'Miss Dist.(miles)', 'Orbiting Body',
       'Orbit ID', 'Orbit Determination Date', 'Orbit Uncertainity',
       'Minimum Orbit Intersection', 'Jupiter Tisserand Invariant',
       'Epoch Osculation', 'Eccentricity', 'Semi Major Axis', 'Inclination',
       'Asc Node Longitude', 'Orbital Period', 'Perihelion Distance',
       'Perihelion Arg', 'Aphelion Dist', 'Perihelion Time', 'Mean Anomaly',
       'Mean Motion', 'Equinox']
x =df[features]
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
a = StandardScaler()
x = a.fit_transform(x)
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(x,label,
                                   random_state=104,  
                                   test_size=0.25,  
                                   shuffle=True)
print(label)
print(x)
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 4682    0
# 4683    0
# 4684    0
# 4685    0
# 4686    0
# Name: Hazardous, Length: 4687, dtype: int64
# [[-0.23104209 -0.20941058 -0.20941058 ...  0.77839321 -0.43110028
#    0.        ]
#  [-0.33482448 -0.15840557 -0.15840557 ... -0.06909298  0.31258164
#    0.        ]
#  [-0.68076581  0.07278876  0.07278876 ...  1.03940428 -0.52211437
#    0.        ]
#  ...
#  [ 0.14949337 -0.34623784 -0.34623784 ...  0.20776991 -0.63207867
#    0.        ]
#  [-0.16185382 -0.23970271 -0.23970271 ...  0.2079915  -0.56766111
#    0.        ]
#  [-1.09278193  0.53049632  0.53049632 ...  0.03397983 -0.54733945
#    0.        ]]

# %%
import pandas
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt

from sklearn.svm import SVC 
clf = SVC(kernel='poly') 

# fitting x samples and y classes 
clf.fit(X_train, y_train)
# Out:
# SVC(kernel='poly')

# %%
from sklearn.metrics import accuracy_score
predicted = clf.predict(X_train)
print (accuracy_score(y_train, predicted))
# Out:
# 0.9129445234708392

# %%
from sklearn.metrics import accuracy_score
predicted = clf.predict(X_test)
print (accuracy_score(y_test, predicted))
# Out:
# 0.893344709897611

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, predicted)
# Out:
# array([[975,  13],
#        [112,  72]], dtype=int64)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.99      0.94       988
#            1       0.85      0.39      0.54       184
#
#     accuracy                           0.89      1172
#    macro avg       0.87      0.69      0.74      1172
# weighted avg       0.89      0.89      0.88      1172
